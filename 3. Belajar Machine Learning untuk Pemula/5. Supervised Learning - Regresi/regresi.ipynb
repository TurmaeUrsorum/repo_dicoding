# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Loading

# %%
df_train = pd.read_csv("./train.csv")
df_test = pd.read_csv("./test.csv")

# %%
df_train.head()
# Out:
#    id  MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 0   0                 5                   8                5              8
# 1   1                 6                   7                4              4
# 2   2                 6                   5                6              7
# 3   3                 3                   4                6              5
# 4   4                 5                   3                2              6
#
#    Urbanization  ClimateChange  DamsQuality  Siltation  AgriculturalPractices  \
# 0             6              4            4          3                      3
# 1             8              8            3          5                      4
# 2             3              7            1          5                      4
# 3             4              8            4          7                      6
# 4             4              4            3          3                      3
#
#    ...  DrainageSystems  CoastalVulnerability  Landslides  Watersheds  \
# 0  ...                5                     3           3           5
# 1  ...                7                     2           0           3
# 2  ...                7                     3           7           5
# 3  ...                2                     4           7           4
# 4  ...                2                     2           6           6
#
#    DeterioratingInfrastructure  PopulationScore  WetlandLoss  \
# 0                            4                7            5
# 1                            5                3            3
# 2                            6                8            2
# 3                            4                6            5
# 4                            4                1            2
#
#    InadequatePlanning  PoliticalFactors  FloodProbability
# 0                   7                 3             0.445
# 1                   4                 3             0.450
# 2                   3                 3             0.530
# 3                   7                 5             0.535
# 4                   3                 5             0.415
#
# [5 rows x 22 columns]

# %%
df_test.head()
# Out:
#         id  MonsoonIntensity  TopographyDrainage  RiverManagement  \
# 0  1117957                 4                   6                3
# 1  1117958                 4                   4                2
# 2  1117959                 1                   3                6
# 3  1117960                 2                   4                4
# 4  1117961                 6                   3                2
#
#    Deforestation  Urbanization  ClimateChange  DamsQuality  Siltation  \
# 0              5             6              7            8          7
# 1              9             5              5            4          7
# 2              5             7              2            4          6
# 3              6             4              5            4          3
# 4              4             6              4            5          5
#
#    AgriculturalPractices  ...  IneffectiveDisasterPreparedness  \
# 0                      8  ...                                8
# 1                      5  ...                                2
# 2                      4  ...                                7
# 3                      4  ...                                7
# 4                      3  ...                                4
#
#    DrainageSystems  CoastalVulnerability  Landslides  Watersheds  \
# 0                5                     7           5           6
# 1                4                     7           4           5
# 2                9                     2           5           5
# 3                8                     4           6           7
# 4                3                     2           6           4
#
#    DeterioratingInfrastructure  PopulationScore  WetlandLoss  \
# 0                            3                6            4
# 1                            1                7            4
# 2                            2                3            6
# 3                            6                4            2
# 4                            6                8            4
#
#    InadequatePlanning  PoliticalFactors
# 0                   4                 5
# 1                   4                 3
# 2                   8                 3
# 3                   4                 4
# 4                   5                 5
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Data Cleaning dan Transformation

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1117957 entries, 0 to 1117956
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count    Dtype
# ---  ------                           --------------    -----
#  0   id                               1117957 non-null  int64
#  1   MonsoonIntensity                 1117957 non-null  int64
#  2   TopographyDrainage               1117957 non-null  int64
#  3   RiverManagement                  1117957 non-null  int64
#  4   Deforestation                    1117957 non-null  int64
#  5   Urbanization                     1117957 non-null  int64
#  6   ClimateChange                    1117957 non-null  int64
#  7   DamsQuality                      1117957 non-null  int64
#  8   Siltation                        1117957 non-null  int64
#  9   AgriculturalPractices            1117957 non-null  int64
#  10  Encroachments                    1117957 non-null  int64
#  11  IneffectiveDisasterPreparedness  1117957 non-null  int64
#  12  DrainageSystems                  1117957 non-null  int64
#  13  CoastalVulnerability             1117957 non-null  int64
#  14  Landslides                       1117957 non-null  int64
#  15  Watersheds                       1117957 non-null  int64
#  16  DeterioratingInfrastructure      1117957 non-null  int64
#  17  PopulationScore                  1117957 non-null  int64
#  18  WetlandLoss                      1117957 non-null  int64
#  19  InadequatePlanning               1117957 non-null  int64
#  20  PoliticalFactors                 1117957 non-null  int64
#  21  FloodProbability                 1117957 non-null  float64
# dtypes: float64(1), int64(21)
# memory usage: 187.6 MB

# %%
df_train.describe(include="all")
# Out:
#                  id  MonsoonIntensity  TopographyDrainage  RiverManagement  \
# count  1.117957e+06      1.117957e+06        1.117957e+06     1.117957e+06
# mean   5.589780e+05      4.921450e+00        4.926671e+00     4.955322e+00
# std    3.227265e+05      2.056387e+00        2.093879e+00     2.072186e+00
# min    0.000000e+00      0.000000e+00        0.000000e+00     0.000000e+00
# 25%    2.794890e+05      3.000000e+00        3.000000e+00     4.000000e+00
# 50%    5.589780e+05      5.000000e+00        5.000000e+00     5.000000e+00
# 75%    8.384670e+05      6.000000e+00        6.000000e+00     6.000000e+00
# max    1.117956e+06      1.600000e+01        1.800000e+01     1.600000e+01
#
#        Deforestation  Urbanization  ClimateChange   DamsQuality     Siltation  \
# count   1.117957e+06  1.117957e+06   1.117957e+06  1.117957e+06  1.117957e+06
# mean    4.942240e+00  4.942517e+00   4.934093e+00  4.955878e+00  4.927791e+00
# std     2.051689e+00  2.083391e+00   2.057742e+00  2.083063e+00  2.065992e+00
# min     0.000000e+00  0.000000e+00   0.000000e+00  0.000000e+00  0.000000e+00
# 25%     4.000000e+00  3.000000e+00   3.000000e+00  4.000000e+00  3.000000e+00
# 50%     5.000000e+00  5.000000e+00   5.000000e+00  5.000000e+00  5.000000e+00
# 75%     6.000000e+00  6.000000e+00   6.000000e+00  6.000000e+00  6.000000e+00
# max     1.700000e+01  1.700000e+01   1.700000e+01  1.600000e+01  1.600000e+01
#
#        AgriculturalPractices  ...  DrainageSystems  CoastalVulnerability  \
# count           1.117957e+06  ...     1.117957e+06          1.117957e+06
# mean            4.942619e+00  ...     4.946893e+00          4.953999e+00
# std             2.068545e+00  ...     2.072333e+00          2.088899e+00
# min             0.000000e+00  ...     0.000000e+00          0.000000e+00
# 25%             3.000000e+00  ...     4.000000e+00          3.000000e+00
# 50%             5.000000e+00  ...     5.000000e+00          5.000000e+00
# 75%             6.000000e+00  ...     6.000000e+00          6.000000e+00
# max             1.600000e+01  ...     1.700000e+01          1.700000e+01
#
#          Landslides    Watersheds  DeterioratingInfrastructure  \
# count  1.117957e+06  1.117957e+06                 1.117957e+06
# mean   4.931376e+00  4.929032e+00                 4.925907e+00
# std    2.078287e+00  2.082395e+00                 2.064813e+00
# min    0.000000e+00  0.000000e+00                 0.000000e+00
# 25%    3.000000e+00  3.000000e+00                 3.000000e+00
# 50%    5.000000e+00  5.000000e+00                 5.000000e+00
# 75%    6.000000e+00  6.000000e+00                 6.000000e+00
# max    1.600000e+01  1.600000e+01                 1.700000e+01
#
#        PopulationScore   WetlandLoss  InadequatePlanning  PoliticalFactors  \
# count     1.117957e+06  1.117957e+06        1.117957e+06      1.117957e+06
# mean      4.927520e+00  4.950859e+00        4.940587e+00      4.939004e+00
# std       2.074176e+00  2.068696e+00        2.081123e+00      2.090350e+00
# min       0.000000e+00  0.000000e+00        0.000000e+00      0.000000e+00
# 25%       3.000000e+00  4.000000e+00        3.000000e+00      3.000000e+00
# 50%       5.000000e+00  5.000000e+00        5.000000e+00      5.000000e+00
# 75%       6.000000e+00  6.000000e+00        6.000000e+00      6.000000e+00
# max       1.800000e+01  1.900000e+01        1.600000e+01      1.600000e+01
#
#        FloodProbability
# count      1.117957e+06
# mean       5.044803e-01
# std        5.102610e-02
# min        2.850000e-01
# 25%        4.700000e-01
# 50%        5.050000e-01
# 75%        5.400000e-01
# max        7.250000e-01
#
# [8 rows x 22 columns]

# %%
missing_value = df_train.isnull().sum()
missing_value[missing_value > 0]
# Out:
# Series([], dtype: int64)

# %%
for features in df_train.columns:
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=df_train[features])
    plt.title(f"boxplot of {features}")
    plt.show()

# %%
Q1 = df_train.quantile(0.25)
Q3 = df_train.quantile(0.75)
IQR = Q3 - Q1

# Contoh sederhana untuk mengidentifikasi outliers menggunakan IQR
Q1 = df_train.quantile(0.25)
Q3 = df_train.quantile(0.75)
IQR = Q3 - Q1
# Filter dataframe untuk hanya menyimpan baris yang tidak mengandung outliers pada kolom numerik
condition = ~((df_train < (Q1 - 1.5 * IQR)) | (df_train > (Q3 + 1.5 * IQR))).any(axis=1)
df = df_train.loc[condition, df_train.columns]

# %%
for features in df.columns:
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=df[features])
    plt.title(f"boxplot of {features}")
    plt.show()

# %%
from sklearn.preprocessing import StandardScaler
 
# Memastikan hanya data dengan tipe numerikal yang akan diproses
numeric_features = df.select_dtypes(include=['number']).columns
 
# Standardisasi fitur numerik
scaler = StandardScaler()
df[numeric_features] = scaler.fit_transform(df[numeric_features])

# %%
df[numeric_features].head()
# Out:
#          id  MonsoonIntensity  TopographyDrainage  RiverManagement  \
# 0 -1.732268          0.058002            1.550328         0.064284
# 1 -1.732265          0.570302            1.050410        -0.468118
# 2 -1.732262          0.570302            0.050574         0.596686
# 3 -1.732259         -0.966598           -0.449345         0.596686
# 4 -1.732256          0.058002           -0.949263        -1.532923
#
#    Deforestation  Urbanization  ClimateChange  DamsQuality  Siltation  \
# 0       1.683351      0.543778      -0.463123    -0.465651  -0.964121
# 1      -0.467537      1.549104       1.573782    -0.998066   0.051310
# 2       1.145629     -0.964210       1.064556    -2.062896   0.051310
# 3       0.070185     -0.461547       1.573782    -0.465651   1.066740
# 4       0.607907     -0.461547      -0.463123    -0.998066  -0.964121
#
#    AgriculturalPractices  ...  DrainageSystems  CoastalVulnerability  \
# 0              -0.969523  ...         0.071054             -0.967507
# 1              -0.463606  ...         1.140054             -1.470036
# 2              -0.463606  ...         1.140054             -0.967507
# 3               0.548227  ...        -1.532446             -0.464978
# 4              -0.969523  ...        -1.532446             -1.470036
#
#    Landslides  Watersheds  DeterioratingInfrastructure  PopulationScore  \
# 0   -0.957953    0.046708                    -0.454798         1.062768
# 1   -2.465862   -0.957783                     0.052873        -0.960584
# 2    1.052592    0.046708                     0.560545         1.568606
# 3    1.052592   -0.455538                    -0.454798         0.556930
# 4    0.549956    0.548954                    -0.454798        -1.972260
#
#    WetlandLoss  InadequatePlanning  PoliticalFactors  FloodProbability
# 0     0.068580            1.048732         -0.959319         -1.122956
# 1    -0.999582           -0.460240         -0.959319         -1.020641
# 2    -1.533663           -0.963231         -0.959319          0.616394
# 3     0.068580            1.048732          0.043751          0.718708
# 4    -1.533663           -0.963231          0.043751         -1.736844
#
# [5 rows x 22 columns]

# %%
for features in df.columns:
    plt.figure(figsize=(10, 6))
    sns.histplot(x=df[features])
    plt.title(f"histogram of {features}")
    plt.show()

# %%
# Mengidentifikasi baris duplikat
duplicates = df.duplicated()
 
print("Baris duplikat:")
print(df[duplicates])
# Out:
# Baris duplikat:
# Empty DataFrame
# Columns: [id, MonsoonIntensity, TopographyDrainage, RiverManagement, Deforestation, Urbanization, ClimateChange, DamsQuality, Siltation, AgriculturalPractices, Encroachments, IneffectiveDisasterPreparedness, DrainageSystems, CoastalVulnerability, Landslides, Watersheds, DeterioratingInfrastructure, PopulationScore, WetlandLoss, InadequatePlanning, PoliticalFactors, FloodProbability]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.describe(include='all')
# Out:
#                  id  MonsoonIntensity  TopographyDrainage  RiverManagement  \
# count  8.458860e+05      8.458860e+05        8.458860e+05     8.458860e+05
# mean   3.128825e-16     -1.722920e-16       -8.252983e-18    -1.122910e-16
# std    1.000001e+00      1.000001e+00        1.000001e+00     1.000001e+00
# min   -1.732268e+00     -2.503498e+00       -2.449018e+00    -2.065325e+00
# 25%   -8.661751e-01     -4.542981e-01       -9.492630e-01    -4.681183e-01
# 50%    2.024918e-05      5.800187e-02        5.057361e-02     6.428396e-02
# 75%    8.661002e-01      5.703019e-01        5.504919e-01     5.966862e-01
# max    1.732027e+00      2.619502e+00        2.550165e+00     2.193893e+00
#
#        Deforestation  Urbanization  ClimateChange   DamsQuality     Siltation  \
# count   8.458860e+05  8.458860e+05   8.458860e+05  8.458860e+05  8.458860e+05
# mean   -1.138030e-16 -1.484907e-17   1.193637e-16  1.572309e-16 -1.516197e-17
# std     1.000001e+00  1.000001e+00   1.000001e+00  1.000001e+00  1.000001e+00
# min    -2.080702e+00 -2.472198e+00  -2.500029e+00 -2.062896e+00 -2.487267e+00
# 25%    -4.675365e-01 -4.615469e-01  -4.631232e-01 -4.656514e-01 -4.564057e-01
# 50%     7.018534e-02  4.111574e-02   4.610324e-02  6.676350e-02  5.130956e-02
# 75%     6.079072e-01  5.437784e-01   5.553296e-01  5.991784e-01  5.590249e-01
# max     2.221073e+00  2.554429e+00   2.592235e+00  2.196423e+00  2.589886e+00
#
#        AgriculturalPractices  ...  DrainageSystems  CoastalVulnerability  \
# count           8.458860e+05  ...     8.458860e+05          8.458860e+05
# mean            1.194309e-16  ...    -2.232715e-17         -1.108210e-16
# std             1.000001e+00  ...     1.000001e+00          1.000001e+00
# min            -2.487272e+00  ...    -2.066946e+00         -2.475094e+00
# 25%            -4.636059e-01  ...    -4.634462e-01         -4.649776e-01
# 50%             4.231074e-02  ...     7.105385e-02          3.755159e-02
# 75%             5.482274e-01  ...     6.055539e-01          5.400808e-01
# max             2.571894e+00  ...     2.209054e+00          2.550197e+00
#
#          Landslides    Watersheds  DeterioratingInfrastructure  \
# count  8.458860e+05  8.458860e+05                 8.458860e+05
# mean  -1.940060e-16 -1.644633e-16                -2.222467e-16
# std    1.000001e+00  1.000001e+00                 1.000001e+00
# min   -2.465862e+00 -2.464520e+00                -2.485485e+00
# 25%   -9.579532e-01 -9.577833e-01                -4.547982e-01
# 50%    4.731955e-02  4.670802e-02                 5.287338e-02
# 75%    5.499559e-01  5.489537e-01                 5.605450e-01
# max    2.560501e+00  2.557936e+00                 2.591231e+00
#
#        PopulationScore   WetlandLoss  InadequatePlanning  PoliticalFactors  \
# count     8.458860e+05  8.458860e+05        8.458860e+05      8.458860e+05
# mean      5.821188e-17  1.895708e-16        1.429887e-16     -7.076985e-17
# std       1.000001e+00  1.000001e+00        1.000001e+00      1.000001e+00
# min      -2.478098e+00 -2.067744e+00       -2.472204e+00     -2.463924e+00
# 25%      -4.547462e-01 -4.655010e-01       -4.602404e-01     -9.593186e-01
# 50%       5.109174e-02  6.857993e-02        4.275047e-02      4.375149e-02
# 75%       5.569297e-01  6.026608e-01        5.457413e-01      5.452865e-01
# max       2.580282e+00  2.204904e+00        2.557705e+00      2.551427e+00
#
#        FloodProbability
# count      8.458860e+05
# mean      -6.328547e-16
# std        1.000001e+00
# min       -2.759991e+00
# 25%       -7.136972e-01
# 50%        2.505596e-03
# 75%        7.187084e-01
# max        2.969631e+00
#
# [8 rows x 22 columns]

# %%
# Menghitung jumlah variabel
num_vars = df.shape[1]
 
# Menentukan jumlah baris dan kolom untuk grid subplot
n_cols = 4  # Jumlah kolom yang diinginkan
n_rows = -(-num_vars // n_cols)  # Ceiling division untuk menentukan jumlah baris
 
# Membuat subplot
fig, axes = plt.subplots(n_rows, n_cols, figsize=(20, n_rows * 4))
 
# Flatten axes array untuk memudahkan iterasi jika diperlukan
axes = axes.flatten()
 
# Plot setiap variabel
for i, column in enumerate(df.drop(columns=["id"]).columns):
    df[column].hist(ax=axes[i], bins=20, edgecolor='black')
    axes[i].set_title(column)
    axes[i].set_xlabel('Value')
    axes[i].set_ylabel('Frequency')
 
# Menghapus subplot yang tidak terpakai (jika ada)
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])
 
# Menyesuaikan layout agar lebih rapi
plt.tight_layout()
plt.show()

# %%
# Menghitung korelasi antara variabel target dan semua variabel lainnya
target_corr = df.corr()['FloodProbability']
 
# (Opsional) Mengurutkan hasil korelasi berdasarkan kekuatan korelasi
target_corr_sorted = target_corr.abs().sort_values(ascending=False)
 
plt.figure(figsize=(10, 6))
target_corr_sorted.plot(kind='bar')
plt.title(f'Correlation with Flood Probability')
plt.xlabel('Variables')
plt.ylabel('Correlation Coefficient')
plt.show()

# %%
import sklearn
from sklearn import datasets
 
# Memisahkan fitur (X) dan target (y)
X = df.drop(columns=['FloodProbability'])
y = df['FloodProbability']
 
from sklearn.model_selection import train_test_split
 
# membagi dataset menjadi training dan testing
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
 
# menghitung panjang/jumlah data
print("Jumlah data: ",len(X))
# menghitung panjang/jumlah data pada x_test
print("Jumlah data latih: ",len(x_train))
# menghitung panjang/jumlah data pada x_test
print("Jumlah data test: ",len(x_test))
# Out:
# Jumlah data:  845886
# Jumlah data latih:  676708
# Jumlah data test:  169178

# %% [markdown]
# ## model lars

# %%
from sklearn import linear_model
lars = linear_model.Lars(n_nonzero_coefs=1).fit(x_train, y_train)
 
pred_lars = lars.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mae_lars = mean_absolute_error(y_test, pred_lars)
mse_lars = mean_squared_error(y_test, pred_lars)
r2_lars = r2_score(y_test, pred_lars)
 
print(f"MAE: {mae_lars}")
print(f"MSE: {mse_lars}")
print(f"R²: {r2_lars}")
# Out:
# MAE: 0.8064965862112847
# MSE: 0.9982455301765664
# R²: 0.0007638833508319953

# %%
# Membuat dictionary untuk menyimpan hasil evaluasi
data = {
    'MAE': [mae_lars],
    'MSE': [mse_lars],
    'R2': [r2_lars]
}
 
# Konversi dictionary menjadi DataFrame
df_results = pd.DataFrame(data, index=['Lars'])
df_results
# Out:
#            MAE       MSE        R2
# Lars  0.806497  0.998246  0.000764

# %% [markdown]
# ## Liniear Regression

# %%
from sklearn.linear_model import LinearRegression
LR = LinearRegression().fit(x_train, y_train)
 
pred_LR = LR.predict(x_test)
 
mae_LR = mean_absolute_error(y_test, pred_LR)
mse_LR = mean_squared_error(y_test, pred_LR)
r2_LR = r2_score(y_test, pred_LR)
 
print(f"MAE: {mae_LR}")
print(f"MSE: {mse_LR}")
print(f"R²: {r2_LR}")
# Out:
# MAE: 0.32914155892050634
# MSE: 0.17129638555662163
# R²: 0.8285336323325565

# %%
df_results.loc['Linear Regression'] = [mae_LR, mse_LR, r2_LR]
df_results
# Out:
#                         MAE       MSE        R2
# Lars               0.806497  0.998246  0.000764
# Linear Regression  0.329142  0.171296  0.828534

# %% [markdown]
# ## model GradientBoostingRegressor

# %%
from sklearn.ensemble import GradientBoostingRegressor
 
GBR = GradientBoostingRegressor(random_state=184)
GBR.fit(x_train, y_train)
 
pred_GBR = GBR.predict(x_test)
 
mae_GBR = mean_absolute_error(y_test, pred_GBR)
mse_GBR = mean_squared_error(y_test, pred_GBR)
r2_GBR = r2_score(y_test, pred_GBR)
 
print(f"MAE: {mae_GBR}")
print(f"MSE: {mse_GBR}")
print(f"R²: {r2_GBR}")
# Out:
# MAE: 0.5126715936448323
# MSE: 0.38049075143226296
# R²: 0.6191316771387398

# %%
df_results.loc['GradientBoostingRegressor'] = [mae_GBR, mse_GBR, r2_GBR]
df_results

# %% [markdown]
# ## model XGBRegressor

# %%
from xgboost import XGBRegressor

# %%
import optuna
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
import numpy as np

# Asumsikan x_train, y_train = DataFrame/Series
# Biar aman, convert ke numpy
X = x_train.to_numpy()
y = y_train.to_numpy()

def objective(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 1000),
        "max_depth": trial.suggest_int("max_depth", 3, 12),
        "learning_rate": trial.suggest_float("learning_rate", 1e-3, 0.3, log=True),
        "subsample": trial.suggest_float("subsample", 0.5, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
        "reg_alpha": trial.suggest_float("reg_alpha", 1e-8, 10.0, log=True),
        "reg_lambda": trial.suggest_float("reg_lambda", 1e-8, 10.0, log=True),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 10),
        "tree_method": "hist",       # lebih cepat
        "objective": "reg:squarederror",
        "random_state": 42,
    }

    kf = KFold(n_splits=3, shuffle=True, random_state=42)
    rmse_scores = []

    for train_idx, val_idx in kf.split(X):
        X_train, X_val = X[train_idx], X[val_idx]
        y_train, y_val = y[train_idx], y[val_idx]

        model = XGBRegressor(**params)
        model.fit(X_train, y_train, eval_set=[(X_val, y_val)], verbose=0)

        preds = model.predict(X_val)
        rmse = mean_squared_error(y_val, preds) ** 0.5
        rmse_scores.append(rmse)

    return np.mean(rmse_scores)

# Jalankan Optuna
study = optuna.create_study(direction="minimize")  # RMSE lebih kecil lebih baik
study.optimize(objective, n_trials=30)

print("Best RMSE:", study.best_value)
print("Best params:", study.best_params)
# Out:
# [I 2025-09-03 14:28:18,507] A new study created in memory with name: no-name-00904239-4ddf-46e1-bcdb-57156acd3686
# [I 2025-09-03 14:30:06,586] Trial 0 finished with value: 0.4623903905137475 and parameters: {'n_estimators': 801, 'max_depth': 8, 'learning_rate': 0.011324955039280405, 'subsample': 0.5257450260725769, 'colsample_bytree': 0.5648153093701547, 'reg_alpha': 1.2135905487221897e-05, 'reg_lambda': 1.2735641566172196, 'min_child_weight': 8}. Best is trial 0 with value: 0.4623903905137475.
# [I 2025-09-03 14:31:27,307] Trial 1 finished with value: 0.43119290548447853 and parameters: {'n_estimators': 601, 'max_depth': 9, 'learning_rate': 0.08251837678727948, 'subsample': 0.7463024006401751, 'colsample_bytree': 0.7188279729412315, 'reg_alpha': 0.011990272304305008, 'reg_lambda': 2.790585983396063e-07, 'min_child_weight': 3}. Best is trial 1 with value: 0.43119290548447853.
# [I 2025-09-03 14:31:40,613] Trial 2 finished with value: 0.7817764655330626 and parameters: {'n_estimators': 145, 'max_depth': 3, 'learning_rate': 0.02855433888787709, 'subsample': 0.7827501679923612, 'colsample_bytree': 0.5251038933883592, 'reg_alpha': 0.0003585125689155061, 'reg_lambda': 3.7736872701059394e-06, 'min_child_weight': 3}. Best is trial 1 with value: 0.43119290548447853.
# [I 2025-09-03 14:33:27,614] Trial 3 finished with value: 0.7170375072674341 and parameters: {'n_estimators': 899, 'max_depth': 6, 'learning_rate': 0.003270327006529756, 'subsample': 0.6540295791138625, 'colsample_bytree': 0.5020050510577659, 'reg_alpha': 2.064723631579637, 'reg_lambda': 2.2866834175889606e-05, 'min_child_weight': 4}. Best is trial 1 with value: 0.43119290548447853.
# [I 2025-09-03 14:34:17,835] Trial 4 finished with value: 0.5981595614874717 and parameters: {'n_estimators': 614, 'max_depth': 6, 'learning_rate': 0.008864357279076286, 'subsample': 0.6942406175436303, 'colsample_bytree': 0.5263405386313262, 'reg_alpha': 0.0917592227288375, 'reg_lambda': 5.0591965806983135, 'min_child_weight': 2}. Best is trial 1 with value: 0.43119290548447853.
# [I 2025-09-03 14:34:37,223] Trial 5 finished with value: 0.9384264489182796 and parameters: {'n_estimators': 279, 'max_depth': 4, 'learning_rate': 0.002436301789895643, 'subsample': 0.7738886706636317, 'colsample_bytree': 0.8746863216455809, 'reg_alpha': 9.092057040405269e-06, 'reg_lambda': 7.315187894360523e-05, 'min_child_weight': 10}. Best is trial 1 with value: 0.43119290548447853.
# [W 2025-09-03 14:36:13,957] Trial 6 failed with parameters: {'n_estimators': 686, 'max_depth': 11, 'learning_rate': 0.0021598403939697493, 'subsample': 0.8637885476154978, 'colsample_bytree': 0.9429592896171315, 'reg_alpha': 0.0014154211684962903, 'reg_lambda': 0.5380822917310679, 'min_child_weight': 4} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/home/brilly/anaconda3/lib/python3.12/site-packages/optuna/study/_optimize.py", line 201, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/tmp/ipykernel_36056/4052046618.py", line 35, in objective
#     model.fit(X_train, y_train, eval_set=[(X_val, y_val)], verbose=0)
#   File "/home/brilly/anaconda3/lib/python3.12/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#            ^^^^^^^^^^^^^^
#   File "/home/brilly/anaconda3/lib/python3.12/site-packages/xgboost/sklearn.py", line 1108, in fit
#     self._Booster = train(
#                     ^^^^^^
#   File "/home/brilly/anaconda3/lib/python3.12/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#            ^^^^^^^^^^^^^^
#   File "/home/brilly/anaconda3/lib/python3.12/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, iteration=i, fobj=obj)
#   File "/home/brilly/anaconda3/lib/python3.12/site-packages/xgboost/core.py", line 2101, in update
#     _LIB.XGBoosterUpdateOneIter(
# KeyboardInterrupt
# [W 2025-09-03 14:36:13,958] Trial 6 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 45
#      43 # Jalankan Optuna
#      44 study = optuna.create_study(direction="minimize")  # RMSE lebih kecil lebih baik
# ---> 45 study.optimize(objective, n_trials=30)
#      47 print("Best RMSE:", study.best_value)
#      48 print("Best params:", study.best_params)
#
# File ~/anaconda3/lib/python3.12/site-packages/optuna/study/study.py:490, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     388 def optimize(
#     389     self,
#     390     func: ObjectiveFuncType,
#    (...)
#     397     show_progress_bar: bool = False,
#     398 ) -> None:
#     399     """Optimize an objective function.
#     400
#     401     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     488             If nested invocation of this method occurs.
#     489     """
# --> 490     _optimize(
#     491         study=self,
#     492         func=func,
#     493         n_trials=n_trials,
#     494         timeout=timeout,
#     495         n_jobs=n_jobs,
#     496         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     497         callbacks=callbacks,
#     498         gc_after_trial=gc_after_trial,
#     499         show_progress_bar=show_progress_bar,
#     500     )
#
# File ~/anaconda3/lib/python3.12/site-packages/optuna/study/_optimize.py:63, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      61 try:
#      62     if n_jobs == 1:
# ---> 63         _optimize_sequential(
#      64             study,
#      65             func,
#      66             n_trials,
#      67             timeout,
#      68             catch,
#      69             callbacks,
#      70             gc_after_trial,
#      71             reseed_sampler_rng=False,
#      72             time_start=None,
#      73             progress_bar=progress_bar,
#      74         )
#      75     else:
#      76         if n_jobs == -1:
#
# File ~/anaconda3/lib/python3.12/site-packages/optuna/study/_optimize.py:160, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     157         break
#     159 try:
# --> 160     frozen_trial_id = _run_trial(study, func, catch)
#     161 finally:
#     162     # The following line mitigates memory problems that can be occurred in some
#     163     # environments (e.g., services that use computing containers such as GitHub Actions).
#     164     # Please refer to the following PR for further details:
#     165     # https://github.com/optuna/optuna/pull/325.
#     166     if gc_after_trial:
#
# File ~/anaconda3/lib/python3.12/site-packages/optuna/study/_optimize.py:258, in _run_trial(study, func, catch)
#     251         assert False, "Should not reach."
#     253 if (
#     254     updated_state == TrialState.FAIL
#     255     and func_err is not None
#     256     and not isinstance(func_err, catch)
#     257 ):
# --> 258     raise func_err
#     259 return trial._trial_id
#
# File ~/anaconda3/lib/python3.12/site-packages/optuna/study/_optimize.py:201, in _run_trial(study, func, catch)
#     199 with get_heartbeat_thread(trial._trial_id, study._storage):
#     200     try:
# --> 201         value_or_values = func(trial)
#     202     except exceptions.TrialPruned as e:
#     203         # TODO(mamu): Handle multi-objective cases.
#     204         state = TrialState.PRUNED
#
# Cell In[42], line 35, in objective(trial)
#      32 y_train, y_val = y[train_idx], y[val_idx]
#      34 model = XGBRegressor(**params)
# ---> 35 model.fit(X_train, y_train, eval_set=[(X_val, y_val)], verbose=0)
#      37 preds = model.predict(X_val)
#      38 rmse = mean_squared_error(y_val, preds) ** 0.5
#
# File ~/anaconda3/lib/python3.12/site-packages/xgboost/core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File ~/anaconda3/lib/python3.12/site-packages/xgboost/sklearn.py:1108, in XGBModel.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1105     obj = None
#    1107 model, metric, params = self._configure_fit(xgb_model, params)
# -> 1108 self._Booster = train(
#    1109     params,
#    1110     train_dmatrix,
#    1111     self.get_num_boosting_rounds(),
#    1112     evals=evals,
#    1113     early_stopping_rounds=self.early_stopping_rounds,
#    1114     evals_result=evals_result,
#    1115     obj=obj,
#    1116     custom_metric=metric,
#    1117     verbose_eval=verbose,
#    1118     xgb_model=model,
#    1119     callbacks=self.callbacks,
#    1120 )
#    1122 self._set_evaluation_result(evals_result)
#    1123 return self
#
# File ~/anaconda3/lib/python3.12/site-packages/xgboost/core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File ~/anaconda3/lib/python3.12/site-packages/xgboost/training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, iteration=i, fobj=obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File ~/anaconda3/lib/python3.12/site-packages/xgboost/core.py:2101, in Booster.update(self, dtrain, iteration, fobj)
#    2097 self._assign_dmatrix_features(dtrain)
#    2099 if fobj is None:
#    2100     _check_call(
# -> 2101         _LIB.XGBoosterUpdateOneIter(
#    2102             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2103         )
#    2104     )
#    2105 else:
#    2106     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
# Fit ulang model dengan param terbaik
best_model = XGBRegressor(**study.best_params)
best_model.fit(X, y)
